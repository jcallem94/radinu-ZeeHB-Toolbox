# %%
f[0,1]=(ml[0]*(Q[0,1]*Q[2,0]-Q[0,0]*Q[2,1])*X[0,0]+ml[3]*(Q[3,2]*(Q[3,3]*X[1,1]-2*Q[1,3]*X[1,3])+Q[1,2]*Q[1,3]*X[3,3]))/\
    (2.*ml[2]*(ml[1]*Q[1,2]*(Q[1,2]*Q[3,1]-Q[1,1]*Q[3,2])+ml[3]*Q[3,2]*(-Q[1,3]*Q[3,2]+Q[1,2]*Q[3,3])))
    
f[1,3]=(Q[3,2]**2*X[1,1]-2*Q[1,2]*Q[3,2]*X[1,3]+Q[1,2]**2*X[3,3])/\
         (2.*(ml[1]*Q[1,2]*(-Q[1,2]*Q[3,1]+Q[1,1]*Q[3,2])+ml[3]*Q[3,2]*(Q[1,3]*Q[3,2]-Q[1,2]*Q[3,3])))
    
f[2,3]=(ml[3]*(Q[1,3]*Q[3,2]-Q[1,2]*Q[3,3])*X[3,3]+ml[1]*(Q[3,1]*(Q[3,2]*X[1,1]-2*Q[1,2]*X[1,3])+Q[1,1]*Q[1,2]*X[3,3]))/\
     (2.*ml[2]*(ml[1]*Q[1,2]*(Q[1,2]*Q[3,1]-Q[1,1]*Q[3,2])+ml[3]*Q[3,2]*(-Q[1,3]*Q[3,2] + Q[1,2]*Q[3,3])))

Q[2,1]=-((ml[1]**3*Q[1,1]*(-Q[1,2]*Q[3,1]+Q[1,1]*Q[3,2])*X[1,1]*(Q[3,1]*(Q[3,2]*X[1,1]-2*Q[1,2]*X[1,3])+\
    Q[1,1]*Q[1,2]*X[3,3])+ml[3]*(Q[1,3]*Q[3,2]-Q[1,2]*Q[3,3])*(ml[3]**2*Q[1,3]*(Q[1,3]*Q[3,2]-Q[1,2]*Q[3,3])*X[3,3]**2+\
    ml[2]**2*Q[3,2]*X[2,2]*(Q[3,2]**2*X[1,1]-2*Q[1,2]*Q[3,2]*X[1,3]+Q[1,2]**2*X[3,3])+ml[2]*ml[3]*X[3,3]*\
    (2*Q[3,2]*(Q[1,3]*Q[3,2]-Q[1,2]*Q[3,3])*X[1,2]+Q[2,2]*(Q[3,2]*(Q[3,3]*X[1,1]-2*Q[1,3]*X[1,3])+\ 
    Q[1,2]*Q[1,3]*X[3,3])))+ml[1]**2*(ml[2]*(Q[1,2]*Q[3,1]-Q[1,1]*Q[3,2])*(-Q[2,2]*X[1,1]+2*Q[1,2]*X[1,2])*\
    (Q[3,1]*(-Q[3,2]*X[1,1]+2*Q[1,2]*X[1,3])-Q[1,1]*Q[1,2]*X[3,3])+ml[3]*(Q[1,1]*Q[3,3]*X[1,1]*\
    (-2*Q[1,1]*Q[1,2]*Q[3,2]*X[3,3]+Q[3,1]*(-Q[3,2]**2*X[1,1]+2*Q[1,2]*Q[3,2]*X[1,3]+Q[1,2]**2*X[3,3]))+\ 
    Q[1,3]*(Q[3,1]**2*(Q[3,2]*X[1,1]-2*Q[1,2]*X[1,3])**2+Q[1,1]**2*Q[3,2]*(Q[3,2]*X[1,1]+2*Q[1,2]*X[1,3])*X[3,3]-\ 
    2*Q[1,1]*Q[3,1]*X[1,3]*(-Q[3,2]**2*X[1,1]+2*Q[1,2]*Q[3,2]*X[1,3]+Q[1,2]**2*X[3,3]))))-\
    ml[1]*(ml[2]**2*Q[1,2]*(Q[1,2]*Q[3,1]-Q[1,1]*Q[3,2])*X[2,2]*(Q[3,2]**2*X[1,1]-2*Q[1,2]*Q[3,2]*X[1,3]+Q[1,2]**2*X[3,3])-\
    ml[3]**2*(Q[1,3]*Q[3,2]-Q[1,2]*Q[3,3])*X[3,3]*(-Q[1,1]*Q[3,2]*Q[3,3]*X[1,1]+Q[1,3]*(2*Q[3,1]*(Q[3,2]*X[1,1]-\
    2*Q[1,2]*X[1,3])+Q[1,1]*(2*Q[3,2]*X[1,3]+Q[1,2]*X[3,3])))+ml[2]*ml[3]*(-2*(Q[1,3]*Q[3,2]-Q[1,2]*Q[3,3])*X[1,2]*\
    (2*Q[1,1]*Q[1,2]*Q[3,2]*X[3,3]+Q[3,1]*(Q[3,2]**2*X[1,1]-2*Q[1,2]*Q[3,2]*X[1,3]-Q[1,2]**2*X[3,3]))+\ 
    Q[2,2]*(Q[1,1]*X[3,3]*(-2*Q[1,2]*Q[3,2]*Q[3,3]*X[1,1]+Q[1,3]*(Q[3,2]**2*X[1,1]+2*Q[1,2]*Q[3,2]*X[1,3]-\ 
    Q[1,2]**2*X[3,3]))+Q[3,1]*(Q[3,2]**2*X[1,1]*(-Q[3,3]*X[1,1]+2*Q[1,3]*X[1,3])+Q[1,2]**2*(Q[3,3]*X[1,1]+\ 
    2*Q[1,3]*X[1,3])*X[3,3]+2*Q[1,2]*Q[3,2]*(Q[3,3]*X[1,1]*X[1,3]-Q[1,3]*(2*X[1,3]**2 + X[1,1]*X[3,3]))))))/\
    (ml[1]*ml[2]*(Q[3,2]**2*X[1,1]-2*Q[1,2]*Q[3,2]*X[1,3]+Q[1,2]**2*X[3,3])*(ml[1]*(-Q[1,2]*Q[3,1]+Q[1,1]*Q[3,2])*X[1,1]-\
     ml[3]*(Q[3,2]*(Q[3,3]*X[1,1] - 2*Q[1,3]*X[1,3])+Q[1,2]*Q[1,3]*X[3,3])))))

Q[2,3]=ml[1]**2*Q[1,1]*(-Q[1,2]*Q[3,1]+Q[1,1]*Q[3,2])*X[1,1]+ml[1]*(-(ml[2]*(Q[1,2]*Q[3,1]-Q[1,1]*Q[3,2])*\
     (-Q[2,2]*X[1,1]+2*Q[1,2]*X[1,2])+ml[3]*(-Q[1,1]*Q[3,2]*Q[3,3]*X[1,1]+Q[1,3]*(2*Q[1,1]*Q[3,2]*X[1,3]+\ 
     Q[3,1]*(Q[3,2]*X[1,1]-2*Q[1,2]*X[1,3]))))+ml[3]*(ml[3]*Q[1,3]*(Q[1,3]*Q[3,2] - Q[1,2]*Q[3,3])*X[3,3]+\ 
     ml[2]*(2*Q[3,2]*(Q[1,3]*Q[3,2]-Q[1,2]*Q[3,3])*X[1,2]+Q[2,2]*(Q[3,2]*(Q[3,3]*X[1,1]-2*Q[1,3]*X[1,3])+\ 
     Q[1,2]*Q[1,3]*X[3,3]))))/(ml[2]*ml[3]*(Q[3,2]**2*X[1,1]-2*Q[1,2]*Q[3,2]*X[1,3]+Q[1,2]**2*X[3,3]))

Q[1,3]=(ml[3]**2*Q[3,3]*X[1,3]*X[3,3]+ml[3]*(2*X[1,3]*(ml[1]*Q[3,1]*X[1,3]+ml[2]*Q[3,2]*X[2,3])-\
     (ml[1]*(Q[3,1]*X[1,1]+Q[1,1]*X[1,3])+ml[2]*(Q[3,2]*X[1,2]+Q[1,2]*X[2,3]))*X[3,3])+\
     Sqrt(ml[3]**2*((-2*X[1,3]*(ml[1]*Q[3,1]*X[1,3]+ml[2]*Q[3,2]*X[2,3])+(ml[1]*Q[3,1]*X[1,1]+(ml[1]*Q[1,1]-\ 
     ml[3]*Q[3,3])*X[1,3]+ml[2]*(Q[3,2]*X[1,2]+Q[1,2]*X[2,3]))*X[3,3])**2-X[3,3]**2*(ml[3]**2*Q[3,3]**2*X[1,1]*X[3,3]+\ 
     ml[1]**2*X[1,1]*(Q[3,1]**2*X[1,1]-2*Q[1,1]*Q[3,1]*X[1,3]+Q[1,1]**2*X[3,3])+ml[2]**2*X[2,2]*(Q[3,2]**2*X[1,1]-\ 
     2*Q[1,2]*Q[3,2]*X[1,3]+Q[1,2]**2*X[3,3])+2*ml[2]*ml[3]*Q[3,3]*(Q[3,2]*X[1,1]*X[2,3]-Q[1,2]*X[1,2]*X[3,3])+\ 
     2*ml[1]*(ml[3]*Q[3,3]*X[1,1]*(Q[3,1]*X[1,3]-Q[1,1]*X[3,3])+ml[2]*(Q[3,1]*(X[1,2]*(Q[3,2]*X[1,1]-2*Q[1,2]*X[1,3])+\
     Q[1,2]*X[1,1]*X[2,3])+Q[1,1]*(-(Q[3,2]*X[1,1]*X[2,3]) + Q[1,2]*X[1,2]*X[3,3])))))))/(ml[3]**2*X[3,3]**2)

# %%
f[0,1]=(ml[0]*(Q[0,1]*Q[2,0]-Q[0,0]*Q[1,0])*X[0,0]+ml[2]*(Q[2,1]*(Q[2,2]*X[0,0]-2*Q[0,2]*X[0,2])+Q[0,1]*Q[0,2]*X[2,2]))/\
    (2.*ml[1]*(ml[0]*Q[0,1]*(Q[0,1]*Q[2,0]-Q[0,0]*Q[2,1])+ml[2]*Q[2,1]*(-Q[0,2]*Q[2,1]+Q[0,1]*Q[2,2])))
    
f[0,2]=(Q[2,1]**2*X[0,0]-2*Q[0,1]*Q[2,1]*X[0,2]+Q[0,1]**2*X[2,2])/\
         (2.*(ml[0]*Q[0,1]*(-Q[0,1]*Q[2,0]+Q[0,0]*Q[2,1])+ml[2]*Q[2,1]*(Q[0,2]*Q[2,1]-Q[0,1]*Q[2,2])))
    
f[1,2]=(ml[2]*(Q[0,2]*Q[2,1]-Q[0,1]*Q[2,2])*X[2,2]+ml[0]*(Q[2,0]*(Q[2,1]*X[0,0]-2*Q[0,1]*X[0,2])+Q[0,0]*Q[0,1]*X[2,2]))/\
     (2.*ml[1]*(ml[0]*Q[0,1]*(Q[0,1]*Q[2,0]-Q[0,0]*Q[2,1])+ml[2]*Q[2,1]*(-Q[0,2]*Q[2,1] + Q[0,1]*Q[2,2])))

Q[1,0]=-((ml[0]**3*Q[0,0]*(-Q[0,1]*Q[2,0]+Q[0,0]*Q[2,1])*X[0,0]*(Q[2,0]*(Q[2,1]*X[0,0]-2*Q[0,1]*X[0,2])+\
    Q[0,0]*Q[0,1]*X[2,2])+ml[2]*(Q[0,2]*Q[2,1]-Q[0,1]*Q[2,2])*(ml[2]**2*Q[0,2]*(Q[0,2]*Q[2,1]-Q[0,1]*Q[2,2])*X[2,2]**2+\
    ml[1]**2*Q[2,1]*X[1,1]*(Q[2,1]**2*X[0,0]-2*Q[0,1]*Q[2,1]*X[0,2]+Q[0,1]**2*X[2,2])+ml[1]*ml[2]*X[2,2]*\
    (2*Q[2,1]*(Q[0,2]*Q[2,1]-Q[0,1]*Q[2,2])*X[0,1]+Q[1,1]*(Q[2,1]*(Q[2,2]*X[0,0]-2*Q[0,2]*X[0,2])+\ 
    Q[0,1]*Q[0,2]*X[2,2])))+ml[0]**2*(ml[1]*(Q[0,1]*Q[2,0]-Q[0,0]*Q[2,1])*(-Q[1,1]*X[0,0]+2*Q[0,1]*X[0,1])*\
    (Q[2,0]*(-Q[2,1]*X[0,0]+2*Q[0,1]*X[0,2])-Q[0,0]*Q[0,1]*X[2,2])+ml[2]*(Q[0,0]*Q[2,2]*X[0,0]*\
    (-2*Q[0,0]*Q[0,1]*Q[2,1]*X[2,2]+Q[2,0]*(-Q[2,1]**2*X[0,0]+2*Q[0,1]*Q[2,1]*X[0,2]+Q[0,1]**2*X[2,2]))+\ 
    Q[0,2]*(Q[2,0]**2*(Q[2,1]*X[0,0]-2*Q[0,1]*X[0,2])**2+Q[0,0]**2*Q[2,1]*(Q[2,1]*X[0,0]+2*Q[0,1]*X[0,2])*X[2,2]-\ 
    2*Q[0,0]*Q[2,0]*X[0,2]*(-Q[2,1]**2*X[0,0]+2*Q[0,1]*Q[2,1]*X[0,2]+Q[0,1]**2*X[2,2]))))-\
    ml[0]*(ml[1]**2*Q[0,1]*(Q[0,1]*Q[2,0]-Q[0,0]*Q[2,1])*X[1,1]*(Q[2,1]**2*X[0,0]-2*Q[0,1]*Q[2,1]*X[0,2]+Q[0,1]**2*X[2,2])-\
    ml[2]**2*(Q[0,2]*Q[2,1]-Q[0,1]*Q[2,2])*X[2,2]*(-Q[0,0]*Q[2,1]*Q[2,2]*X[0,0]+Q[0,2]*(2*Q[2,0]*(Q[2,1]*X[0,0]-\
    2*Q[0,1]*X[0,2])+Q[0,0]*(2*Q[2,1]*X[0,2]+Q[0,1]*X[2,2])))+ml[1]*ml[2]*(-2*(Q[0,2]*Q[2,1]-Q[0,1]*Q[2,2])*X[0,1]*\
    (2*Q[0,0]*Q[0,1]*Q[2,1]*X[2,2]+Q[2,0]*(Q[2,1]**2*X[0,0]-2*Q[0,1]*Q[2,1]*X[0,2]-Q[0,1]**2*X[2,2]))+\ 
    Q[1,1]*(Q[0,0]*X[2,2]*(-2*Q[0,1]*Q[2,1]*Q[2,2]*X[0,0]+Q[0,2]*(Q[2,1]**2*X[0,0]+2*Q[0,1]*Q[2,1]*X[0,2]-\ 
    Q[0,1]**2*X[2,2]))+Q[2,0]*(Q[2,1]**2*X[0,0]*(-Q[2,2]*X[0,0]+2*Q[0,2]*X[0,2])+Q[0,1]**2*(Q[2,2]*X[0,0]+\ 
    2*Q[0,2]*X[0,2])*X[2,2]+2*Q[0,1]*Q[2,1]*(Q[2,2]*X[0,0]*X[0,2]-Q[0,2]*(2*X[0,2]**2 + X[0,0]*X[2,2]))))))/\
    (ml[0]*ml[1]*(Q[2,1]**2*X[0,0]-2*Q[0,1]*Q[2,1]*X[0,2]+Q[0,1]**2*X[2,2])*(ml[0]*(-Q[0,1]*Q[2,0]+Q[0,0]*Q[2,1])*X[0,0]-\
     ml[2]*(Q[2,1]*(Q[2,2]*X[0,0] - 2*Q[0,2]*X[0,2])+Q[0,1]*Q[0,2]*X[2,2])))))

Q[1,2]=ml[0]**2*Q[0,0]*(-Q[0,1]*Q[2,0]+Q[0,0]*Q[2,1])*X[0,0]+ml[0]*(-(ml[1]*(Q[0,1]*Q[2,0]-Q[0,0]*Q[2,1])*\
     (-Q[1,1]*X[0,0]+2*Q[0,1]*X[0,1])+ml[2]*(-Q[0,0]*Q[2,1]*Q[2,2]*X[0,0]+Q[0,2]*(2*Q[0,0]*Q[2,1]*X[0,2]+\ 
     Q[2,0]*(Q[2,1]*X[0,0]-2*Q[0,1]*X[0,2]))))+ml[2]*(ml[2]*Q[0,2]*(Q[0,2]*Q[2,1] - Q[0,1]*Q[2,2])*X[2,2]+\ 
     ml[1]*(2*Q[2,1]*(Q[0,2]*Q[2,1]-Q[0,1]*Q[2,2])*X[0,1]+Q[1,1]*(Q[2,1]*(Q[2,2]*X[0,0]-2*Q[0,2]*X[0,2])+\ 
     Q[0,1]*Q[0,2]*X[2,2]))))/(ml[1]*ml[2]*(Q[2,1]**2*X[0,0]-2*Q[0,1]*Q[2,1]*X[0,2]+Q[0,1]**2*X[2,2]))

Q[0,2]=(ml[2]**2*Q[2,2]*X[0,2]*X[2,2]+ml[2]*(2*X[0,2]*(ml[0]*Q[2,0]*X[0,2]+ml[1]*Q[2,1]*X[1,2])-\
     (ml[0]*(Q[2,0]*X[0,0]+Q[0,0]*X[0,2])+ml[1]*(Q[2,1]*X[0,1]+Q[0,1]*X[1,2]))*X[2,2])+\
     Sqrt(ml[2]**2*((-2*X[0,2]*(ml[0]*Q[2,0]*X[0,2]+ml[1]*Q[2,1]*X[1,2])+(ml[0]*Q[2,0]*X[0,0]+(ml[0]*Q[0,0]-\ 
     ml[2]*Q[2,2])*X[0,2]+ml[1]*(Q[2,1]*X[0,1]+Q[0,1]*X[1,2]))*X[2,2])**2-X[2,2]**2*(ml[2]**2*Q[2,2]**2*X[0,0]*X[2,2]+\ 
     ml[0]**2*X[0,0]*(Q[2,0]**2*X[0,0]-2*Q[0,0]*Q[2,0]*X[0,2]+Q[0,0]**2*X[2,2])+ml[1]**2*X[1,1]*(Q[2,1]**2*X[0,0]-\ 
     2*Q[0,1]*Q[2,1]*X[0,2]+Q[0,1]**2*X[2,2])+2*ml[1]*ml[2]*Q[2,2]*(Q[2,1]*X[0,0]*X[1,2]-Q[0,1]*X[0,1]*X[2,2])+\ 
     2*ml[0]*(ml[2]*Q[2,2]*X[0,0]*(Q[2,0]*X[0,2]-Q[0,0]*X[2,2])+ml[1]*(Q[2,0]*(X[0,1]*(Q[2,1]*X[0,0]-2*Q[0,1]*X[0,2])+\
     Q[0,1]*X[0,0]*X[1,2])+Q[0,0]*(-(Q[2,1]*X[0,0]*X[1,2]) + Q[0,1]*X[0,1]*X[2,2])))))))/(ml[2]**2*X[2,2]**2)

# %%
Q(2,1)=-((ml(1)**3*Q(1,1)*(-Q(1,2)*Q(3,1)+Q(1,1)*Q(3,2))*X(1,1)*(Q(3,1)*(Q(3,2)*X(1,1)-2*Q(1,2)*X(1,3))+
    Q(1,1)*Q(1,2)*X(3,3))+ml(3)*(Q(1,3)*Q(3,2)-Q(1,2)*Q(3,3))*(ml(3)**2*Q(1,3)*(Q(1,3)*Q(3,2)- 
    Q(1,2)*Q(3,3))*X(3,3)**2+ml(2)**2*Q(3,2)*X(2,2)*(Q(3,2)**2*X(1,1)-2*Q(1,2)*Q(3,2)*X(1,3)+Q(1,2)**2*X(3,3)) + 
    ml(2)*ml(3)*X(3,3)*(2*Q(3,2)*(Q(1,3)*Q(3,2)-Q(1,2)*Q(3,3))*X(1,2)+Q(2,2)*(Q(3,2)*(Q(3,3)*X(1,1)-2*Q(1,3)*X(1,3)) + 
    Q(1,2)*Q(1,3)*X(3,3))))+ml(1)**2*(ml(2)*(Q(1,2)*Q(3,1)-Q(1,1)*Q(3,2))*(-(Q(2,2)*X(1,1)) + 2*Q(1,2)*X(1,2))*
    (Q(3,1)*(-(Q(3,2)*X(1,1)) + 2*Q(1,2)*X(1,3)) - Q(1,1)*Q(1,2)*X(3,3))+ ml(3)*(Q(1,1)*Q(3,3)*X(1,1)*
    (-2*Q(1,1)*Q(1,2)*Q(3,2)*X(3,3) + Q(3,1)*(-(Q(3,2)**2*X(1,1)) + 2*Q(1,2)*Q(3,2)*X(1,3) + Q(1,2)**2*X(3,3))) + 
    Q(1,3)*(Q(3,1)**2*(Q(3,2)*X(1,1) - 2*Q(1,2)*X(1,3))**2 + Q(1,1)**2*Q(3,2)*(Q(3,2)*X(1,1) + 2*Q(1,2)*X(1,3))*X(3,3) - 
    2*Q(1,1)*Q(3,1)*X(1,3)*(-(Q(3,2)**2*X(1,1)) + 2*Q(1,2)*Q(3,2)*X(1,3) + Q(1,2)**2*X(3,3))))) - 
    ml(1)*(ml(2)**2*Q(1,2)*(Q(1,2)*Q(3,1) - Q(1,1)*Q(3,2))*X(2,2)*(Q(3,2)**2*X(1,1) - 2*Q(1,2)*Q(3,2)*X(1,3) + 
    Q(1,2)**2*X(3,3)) - ml(3)**2*(Q(1,3)*Q(3,2) - Q(1,2)*Q(3,3))*X(3,3)*(-(Q(1,1)*Q(3,2)*Q(3,3)*X(1,1)) + 
    Q(1,3)*(2*Q(3,1)*(Q(3,2)*X(1,1) - 2*Q(1,2)*X(1,3)) + Q(1,1)*(2*Q(3,2)*X(1,3) + Q(1,2)*X(3,3)))) + 
    ml(2)*ml(3)*(-2*(Q(1,3)*Q(3,2) - Q(1,2)*Q(3,3))*X(1,2)*(2*Q(1,1)*Q(1,2)*Q(3,2)*X(3,3) + 
    Q(3,1)*(Q(3,2)**2*X(1,1) - 2*Q(1,2)*Q(3,2)*X(1,3) - Q(1,2)**2*X(3,3))) + Q(2,2)*(Q(1,1)*X(3,3)*
    (-2*Q(1,2)*Q(3,2)*Q(3,3)*X(1,1) + Q(1,3)*(Q(3,2)**2*X(1,1) + 2*Q(1,2)*Q(3,2)*X(1,3) - Q(1,2)**2*X(3,3))) + 
    Q(3,1)*(Q(3,2)**2*X(1,1)*(-(Q(3,3)*X(1,1)) + 2*Q(1,3)*X(1,3)) + Q(1,2)**2*(Q(3,3)*X(1,1) + 2*Q(1,3)*X(1,3))*X(3,3) + 
    2*Q(1,2)*Q(3,2)*(Q(3,3)*X(1,1)*X(1,3) - Q(1,3)*(2*X(1,3)**2 + X(1,1)*X(3,3))))))))/
    (ml(1)*ml(2)*(Q(3,2)**2*X(1,1) - 2*Q(1,2)*Q(3,2)*X(1,3) + Q(1,2)**2*X(3,3))*(ml(1)*(-(Q(1,2)*Q(3,1)) + 
    Q(1,1)*Q(3,2))*X(1,1) - ml(3)*(Q(3,2)*(Q(3,3)*X(1,1) - 2*Q(1,3)*X(1,3)) + Q(1,2)*Q(1,3)*X(3,3)))))


Q[1,0]=-((ml[0]**3*Q[0,0]*(-Q[0,1]*Q[2,0]+Q[0,0]*Q[2,1])*X[0,0]*(Q[2,0]*(Q[2,1]*X[0,0]-2*Q[0,1]*X[0,2])+
    Q[0,0]*Q[0,1]*X[2,2])+ml[2]*(Q[0,2]*Q[2,1]-Q[0,1]*Q[2,2])*(ml[2]**2*Q[0,2]*(Q[0,2]*Q[2,1]- 
    Q[0,1]*Q[2,2])*X[2,2]**2+ml[1]**2*Q[2,1]*X[1,1]*(Q[2,1]**2*X[0,0]-2*Q[0,1]*Q[2,1]*X[0,2]+Q[0,1]**2*X[2,2]) + 
    ml[1]*ml[2]*X[2,2]*(2*Q[2,1]*(Q[0,2]*Q[2,1]-Q[0,1]*Q[2,2])*X[0,1]+Q[1,1]*(Q[2,1]*(Q[2,2]*X[0,0]-2*Q[0,2]*X[0,2]) + 
    Q[0,1]*Q[0,2]*X[2,2])))+ml[0]**2*(ml[1]*(Q[0,1]*Q[2,0]-Q[0,0]*Q[2,1])*(-(Q[1,1]*X[0,0]) + 2*Q[0,1]*X[0,1])*
    (Q[2,0]*(-(Q[2,1]*X[0,0]) + 2*Q[0,1]*X[0,2]) - Q[0,0]*Q[0,1]*X[2,2])+ ml[2]*(Q[0,0]*Q[2,2]*X[0,0]*
    (-2*Q[0,0]*Q[0,1]*Q[2,1]*X[2,2] + Q[2,0]*(-(Q[2,1]**2*X[0,0]) + 2*Q[0,1]*Q[2,1]*X[0,2] + Q[0,1]**2*X[2,2])) + 
    Q[0,2]*(Q[2,0]**2*(Q[2,1]*X[0,0] - 2*Q[0,1]*X[0,2])**2 + Q[0,0]**2*Q[2,1]*(Q[2,1]*X[0,0] + 2*Q[0,1]*X[0,2])*X[2,2] - 
    2*Q[0,0]*Q[2,0]*X[0,2]*(-(Q[2,1]**2*X[0,0]) + 2*Q[0,1]*Q[2,1]*X[0,2] + Q[0,1]**2*X[2,2])))) - 
    ml[0]*(ml[1]**2*Q[0,1]*(Q[0,1]*Q[2,0] - Q[0,0]*Q[2,1])*X[1,1]*(Q[2,1]**2*X[0,0] - 2*Q[0,1]*Q[2,1]*X[0,2] + 
    Q[0,1]**2*X[2,2]) - ml[2]**2*(Q[0,2]*Q[2,1] - Q[0,1]*Q[2,2])*X[2,2]*(-(Q[0,0]*Q[2,1]*Q[2,2]*X[0,0]) + 
    Q[0,2]*(2*Q[2,0]*(Q[2,1]*X[0,0] - 2*Q[0,1]*X[0,2]) + Q[0,0]*(2*Q[2,1]*X[0,2] + Q[0,1]*X[2,2]))) + 
    ml[1]*ml[2]*(-2*(Q[0,2]*Q[2,1] - Q[0,1]*Q[2,2])*X[0,1]*(2*Q[0,0]*Q[0,1]*Q[2,1]*X[2,2] + 
    Q[2,0]*(Q[2,1]**2*X[0,0] - 2*Q[0,1]*Q[2,1]*X[0,2] - Q[0,1]**2*X[2,2])) + Q[1,1]*(Q[0,0]*X[2,2]*
    (-2*Q[0,1]*Q[2,1]*Q[2,2]*X[0,0] + Q[0,2]*(Q[2,1]**2*X[0,0] + 2*Q[0,1]*Q[2,1]*X[0,2] - Q[0,1]**2*X[2,2])) + 
    Q[2,0]*(Q[2,1]**2*X[0,0]*(-(Q[2,2]*X[0,0]) + 2*Q[0,2]*X[0,2]) + Q[0,1]**2*(Q[2,2]*X[0,0] + 2*Q[0,2]*X[0,2])*X[2,2] + 
    2*Q[0,1]*Q[2,1]*(Q[2,2]*X[0,0]*X[0,2] - Q[0,2]*(2*X[0,2]**2 + X[0,0]*X[2,2])))))))/
    (ml[0]*ml[1]*(Q[2,1]**2*X[0,0] - 2*Q[0,1]*Q[2,1]*X[0,2] + Q[0,1]**2*X[2,2])*(ml[0]*(-(Q[0,1]*Q[2,0]) + 
    Q[0,0]*Q[2,1])*X[0,0] - ml[2]*(Q[2,1]*(Q[2,2]*X[0,0] - 2*Q[0,2]*X[0,2]) + Q[0,1]*Q[0,2]*X[2,2]))))
